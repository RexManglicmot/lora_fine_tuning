# %%
import pandas as pd
import re
import os

# %%
df_kaggle = pd.read_csv(
    "./data/raw/alldata_1_for_kaggle.csv",
    encoding="ISO-8859-1",
    on_bad_lines="skip",
    engine="python"
)

# %%
# Originally was in my MacOS for processsing

# df_kaggle = pd.read_csv(
#     "/Users/Rex/vscode/ai_lora_tuning/alldata_1_for_kaggle.csv",
#     encoding="ISO-8859-1",
#     on_bad_lines="skip",
#     engine="python"
# )

# %%
df_kaggle.head(50)
# Out:
#     Unnamed: 0               0  \
# 0            0  Thyroid_Cancer
# 1            1  Thyroid_Cancer
# 2            2  Thyroid_Cancer
# 3            3  Thyroid_Cancer
# 4            4  Thyroid_Cancer
# 5            5  Thyroid_Cancer
# 6            6  Thyroid_Cancer
# 7            7  Thyroid_Cancer
# 8            8  Thyroid_Cancer
# 9            9  Thyroid_Cancer
# 10          10  Thyroid_Cancer
# 11          11  Thyroid_Cancer
# 12          12  Thyroid_Cancer
# 13          13  Thyroid_Cancer
# 14          14  Thyroid_Cancer
# 15          15  Thyroid_Cancer
# 16          16  Thyroid_Cancer
# 17          17  Thyroid_Cancer
# 18          18  Thyroid_Cancer
# 19          19  Thyroid_Cancer
# 20          20  Thyroid_Cancer
# 21          21  Thyroid_Cancer
# 22          22  Thyroid_Cancer
# 23          23  Thyroid_Cancer
# 24          24  Thyroid_Cancer
# 25          25  Thyroid_Cancer
# 26          26  Thyroid_Cancer
# 27          27  Thyroid_Cancer
# 28          28  Thyroid_Cancer
# 29          29  Thyroid_Cancer
# 30          30  Thyroid_Cancer
# 31          31  Thyroid_Cancer
# 32          32  Thyroid_Cancer
# 33          33  Thyroid_Cancer
# 34          34  Thyroid_Cancer
# 35          35  Thyroid_Cancer
# 36          36  Thyroid_Cancer
# 37          37  Thyroid_Cancer
# 38          38  Thyroid_Cancer
# 39          39  Thyroid_Cancer
# 40          40  Thyroid_Cancer
# 41          41  Thyroid_Cancer
# 42          42  Thyroid_Cancer
# 43          43  Thyroid_Cancer
# 44          44  Thyroid_Cancer
# 45          45  Thyroid_Cancer
# 46          46  Thyroid_Cancer
# 47          47  Thyroid_Cancer
# 48          48  Thyroid_Cancer
# 49          49  Thyroid_Cancer
#
#                                                     a
# 0   Thyroid surgery in  children in a single insti...
# 1   " The adopted strategy was the same as that us...
# 2   coronary arterybypass grafting thrombosis ï¬b...
# 3    Solitary plasmacytoma SP of the skull is an u...
# 4    This study aimed to investigate serum matrix ...
# 5    This study was performed to explore the effec...
# 6    This study was performed assess the clinical ...
# 7   Journal of International Medical Research  Th...
# 8    Gastric cancer GC persists as a worldwide pub...
# 9    Scars Burns  HealingVolume     reuse guideli...
# 10   In  a novel coronavirus SARSCoV2 was found to...
# 11   Cabozantinib is an oral multikinase inhibitor...
# 12  " Despite several efforts the development of a...
# 13   Purpose of Review Recognize which are the ele...
# 14  Neurologic Manifestations of Systemic Disease ...
# 15  EndocrinesyPostoperative vocal fold dysfunctio...
# 16  Neck Tissues A a0Systematic ReviewJerome a0R a...
# 17  Molecular Medicine The role of selenium metabo...
# 18  increasing relevancy of geospatial technologie...
# 19  generate a map of the copy number variations C...
# 20  patients who have diabetes suffer from Type  D...
# 21  "Early detection of capecitabineresistance cou...
# 22  "Postoperative pain in ambulatory surgery is a...
# 23  "Pressure sores are sometimes refractory to tr...
# 24  "variability around prevalence estimates of mu...
# 25  "Older patients with cancer require specific a...
# 26  "Sleep disturbance is an issue reported by car...
# 27  "Age is associated with the prognosis of gliom...
# 28  "Previous evidence has suggested that lower ge...
# 29  "Accumulating evidence has revealed the critic...
# 30  "Tumor microenvironment TME plays an important...
# 31  "At the time of surgery approximately  of the...
# 32  "At present the relationship between hypothyro...
# 33  "Sintilimab blocks the interaction between pro...
# 34  "Trophoblast cell surface antigen  TROP2 is ov...
# 35  "Nonsmall cell lung cancer is the most common ...
# 36  "patients with differentiated thyroid cancer D...
# 37  "Sphingosine1phosphate receptor S1PR1 is invol...
# 38  "Gastric neoplasms containing neuroendocrine c...
# 39  "Meningiomas are the most common primary centr...
# 40  "incidence of thyroid carcinoma is increasing ...
# 41  "diagnostic performance of intravoxel incohere...
# 42  "Microwave ablation MWA is widely used to trea...
# 43  "Lung adenocarcinoma LAD is a prevalent type o...
# 44  "characterize the frequency and clinical featu...
# 45  "Effects of lowdose computed tomography LDCT s...
# 46  "differentiation of human stromal mesenchymal ...
# 47  "increasing number of studies have focused on ...
# 48  "Immune checkpoint inhibitors ICIs can induce ...
# 49  "attention has been paid to whether snoring fr...

# %%
df_kaggle.shape
# Out:
# (7570, 3)

# %%
unique = df_kaggle['0'].value_counts()
print(unique)
# Out:
# 0
# Thyroid_Cancer    2810
# Colon_Cancer      2580
# Lung_Cancer       2180
# Name: count, dtype: int64

# %%
def clean_biomed_csv(input_csv_path: str, output_csv_path: str = None):
    """
    Cleans a biomedical text CSV by:
      - Handling non-UTF-8 encodings (cp1252, ISO-8859-1)
      - Stripping non-word symbols except punctuation and spaces
      - Saving the cleaned version as a new CSV
    """
    encodings_to_try = ["utf-8", "cp1252", "ISO-8859-1"]
    df = None
    for enc in encodings_to_try:
        try:
            df = pd.read_csv(input_csv_path, encoding=enc, on_bad_lines="skip", engine="python")
            print(f"Loaded CSV using encoding: {enc}")
            break
        except UnicodeDecodeError:
            print(f"Failed with encoding: {enc}, trying next...")
    
    if df is None:
        raise ValueError("Could not load the CSV with the tried encodings.")

    def clean_text(text):
        if pd.isna(text):
            return text
        text = str(text)

        # --- HARD REMOVE ALL DOUBLE QUOTES so """ cannot appear ---
        # (removes any sequence of one or more " characters)
        text = re.sub(r'"+', '', text)

        # keep your original cleaning
        text = re.sub(r"[^\w\s.,!?;:'\"()-]", " ", text)  # Remove unwanted characters (quotes already removed)
        text = re.sub(r"\s+", " ", text)                  # Normalize spaces
        return text.strip()

    for col in df.select_dtypes(include=["object"]).columns:
        df[col] = df[col].apply(clean_text)

    if not output_csv_path:
        base, ext = os.path.splitext(input_csv_path)
        output_csv_path = f"{base}_cleaned{ext}"

    df.to_csv(output_csv_path, index=False)
    print(f"Cleaned CSV saved to: {output_csv_path}")

    return output_csv_path


# --------------------------
# Example usage in same notebook
# --------------------------
input_path = "./data/raw/alldata_1_for_kaggle.csv"
output_path = "./data/processed/alldata_1_for_kaggle_cleaned.csv"
cleaned_path = clean_biomed_csv(input_path, output_csv_path=output_path)

# Load the cleaned CSV to check
df_cleaned = pd.read_csv(cleaned_path)
df_cleaned.head()
# Out:
# Failed with encoding: utf-8, trying next...
# Failed with encoding: cp1252, trying next...
# Loaded CSV using encoding: ISO-8859-1
# Cleaned CSV saved to: ./data/raw/alldata_1_for_kaggle_cleaned.csv
#    Unnamed: 0               0  \
# 0           0  Thyroid_Cancer
# 1           1  Thyroid_Cancer
# 2           2  Thyroid_Cancer
# 3           3  Thyroid_Cancer
# 4           4  Thyroid_Cancer
#
#                                                    a
# 0  Thyroid surgery in children in a single instit...
# 1  The adopted strategy was the same as that used...
# 2  coronary arterybypass grafting thrombosis ï br...
# 3  Solitary plasmacytoma SP of the skull is an un...
# 4  This study aimed to investigate serum matrix m...

# %%
df_cleaned.columns
# Out:
# Index(['Unnamed: 0', '0', 'a'], dtype='object')

# %%
df_cleaned = df_cleaned.drop(columns=['Unnamed: 0'])
df_cleaned = df_cleaned.rename(columns={'0': 'label', 'a': 'text'})

# %%
df_cleaned.head(50)
# Out:
#              label                                               text
# 0   Thyroid_Cancer  Thyroid surgery in children in a single instit...
# 1   Thyroid_Cancer  The adopted strategy was the same as that used...
# 2   Thyroid_Cancer  coronary arterybypass grafting thrombosis ï br...
# 3   Thyroid_Cancer  Solitary plasmacytoma SP of the skull is an un...
# 4   Thyroid_Cancer  This study aimed to investigate serum matrix m...
# 5   Thyroid_Cancer  This study was performed to explore the effect...
# 6   Thyroid_Cancer  This study was performed assess the clinical o...
# 7   Thyroid_Cancer  Journal of International Medical Research The ...
# 8   Thyroid_Cancer  Gastric cancer GC persists as a worldwide publ...
# 9   Thyroid_Cancer  Scars Burns HealingVolume reuse guidelinessage...
# 10  Thyroid_Cancer  In a novel coronavirus SARSCoV2 was found to c...
# 11  Thyroid_Cancer  Cabozantinib is an oral multikinase inhibitor ...
# 12  Thyroid_Cancer  Despite several efforts the development of an ...
# 13  Thyroid_Cancer  Purpose of Review Recognize which are the elem...
# 14  Thyroid_Cancer  Neurologic Manifestations of Systemic Disease ...
# 15  Thyroid_Cancer  EndocrinesyPostoperative vocal fold dysfunctio...
# 16  Thyroid_Cancer  Neck Tissues A a0Systematic ReviewJerome a0R a...
# 17  Thyroid_Cancer  Molecular Medicine The role of selenium metabo...
# 18  Thyroid_Cancer  increasing relevancy of geospatial technologie...
# 19  Thyroid_Cancer  generate a map of the copy number variations C...
# 20  Thyroid_Cancer  patients who have diabetes suffer from Type DM...
# 21  Thyroid_Cancer  Early detection of capecitabineresistance coul...
# 22  Thyroid_Cancer  Postoperative pain in ambulatory surgery is a ...
# 23  Thyroid_Cancer  Pressure sores are sometimes refractory to tre...
# 24  Thyroid_Cancer  variability around prevalence estimates of mul...
# 25  Thyroid_Cancer  Older patients with cancer require specific an...
# 26  Thyroid_Cancer  Sleep disturbance is an issue reported by care...
# 27  Thyroid_Cancer  Age is associated with the prognosis of glioma...
# 28  Thyroid_Cancer  Previous evidence has suggested that lower ges...
# 29  Thyroid_Cancer  Accumulating evidence has revealed the critica...
# 30  Thyroid_Cancer  Tumor microenvironment TME plays an important ...
# 31  Thyroid_Cancer  At the time of surgery approximately of the pa...
# 32  Thyroid_Cancer  At present the relationship between hypothyroi...
# 33  Thyroid_Cancer  Sintilimab blocks the interaction between prog...
# 34  Thyroid_Cancer  Trophoblast cell surface antigen TROP2 is over...
# 35  Thyroid_Cancer  Nonsmall cell lung cancer is the most common c...
# 36  Thyroid_Cancer  patients with differentiated thyroid cancer DT...
# 37  Thyroid_Cancer  Sphingosine1phosphate receptor S1PR1 is involv...
# 38  Thyroid_Cancer  Gastric neoplasms containing neuroendocrine ca...
# 39  Thyroid_Cancer  Meningiomas are the most common primary centra...
# 40  Thyroid_Cancer  incidence of thyroid carcinoma is increasing a...
# 41  Thyroid_Cancer  diagnostic performance of intravoxel incoheren...
# 42  Thyroid_Cancer  Microwave ablation MWA is widely used to treat...
# 43  Thyroid_Cancer  Lung adenocarcinoma LAD is a prevalent type of...
# 44  Thyroid_Cancer  characterize the frequency and clinical featur...
# 45  Thyroid_Cancer  Effects of lowdose computed tomography LDCT sc...
# 46  Thyroid_Cancer  differentiation of human stromal mesenchymal s...
# 47  Thyroid_Cancer  increasing number of studies have focused on t...
# 48  Thyroid_Cancer  Immune checkpoint inhibitors ICIs can induce i...
# 49  Thyroid_Cancer  attention has been paid to whether snoring fre...

# %%
unique = df_cleaned['label'].value_counts()
print(unique)
# Out:
# label
# Thyroid_Cancer    2810
# Colon_Cancer      2580
# Lung_Cancer       2180
# Name: count, dtype: int64

# %%
df_cleaned.columns
# Out:
# Index(['label', 'text'], dtype='object')

# %%
# Save DataFrame to CSV
df_cleaned.to_csv("./data/processed/df_cleaned.csv", index=False)

# 10/10/25
# Was quick
# Next, is prepare_data.py
